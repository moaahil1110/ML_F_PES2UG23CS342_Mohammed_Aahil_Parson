# %% [markdown]
# **Objective**: In this lab, you will implement and compare manual grid search with scikit-learn's built-in GridSearchCV for hyperparameter tuning. You'll work with multiple classification algorithms and combine them using voting classifiers.
#
# **Learning Goals**:
# - Understand hyperparameter tuning through grid search
# - Compare manual implementation with built-in functions
# - Learn to create and evaluate voting classifiers
# - Work with multiple real-world datasets
# - Visualize model performance using ROC curves and confusion matrices
#
# **Datasets Used**:
# 1. Wine Quality - Predicting wine quality based on chemical properties
# 2. HR Attrition - Predicting employee turnover
# 3. Banknote Authentication - Detecting counterfeit banknotes
# 4. QSAR Biodegradation - Predicting chemical biodegradability

# %% [markdown]
# ## Part 1: Import Libraries and Setup
#
# First, let's import all the necessary libraries for our machine learning pipeline.

# %%
import pandas as pd
import numpy as np
import itertools
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import VotingClassifier
from sklearn.metrics import (accuracy_score, precision_score, recall_score,
                             f1_score, roc_auc_score, roc_curve,
                             confusion_matrix, ConfusionMatrixDisplay, classification_report)
# Bypass SSL certificate verification for dataset downloads
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %% [markdown]
# # Models and Parameter Grids

# %%
# The parameter names must match the pipeline step names, e.g., 'classifier__max_depth'
# TODO: Define base models (Decision Tree, kNN, Logistic Regression)

# Define the three base models (Decision Tree, kNN, Logistic Regression)
dt = DecisionTreeClassifier(random_state=42)
knn = KNeighborsClassifier()
lr = LogisticRegression(random_state=42, max_iter=1000)

param_grid_dt = {
    'feature_selection__k': [5, 10, 15, 20],
    'classifier__max_depth': [3, 5, 7, 10, None],
    'classifier__min_samples_split': [2, 5, 10],
    'classifier__min_samples_leaf': [1, 2, 4]
}

param_grid_knn = {
    'feature_selection__k': [5, 10, 15, 20],  
    'classifier__n_neighbors': [3, 5, 7, 9, 11],
    'classifier__weights': ['uniform', 'distance'],
    'classifier__metric': ['euclidean', 'manhattan']
}

param_grid_lr = {
    'feature_selection__k': [5, 10, 15, 20],
    'classifier__C': [0.01, 0.1, 1, 10, 100],
    'classifier__penalty': ['l1', 'l2'],
    'classifier__solver': ['liblinear', 'saga']
}

# Create a list of (classifier, param_grid, name) tuples
classifiers_to_tune = [
    (dt, param_grid_dt, 'Decision Tree'),
    (knn, param_grid_knn, 'k-NN'),
    (lr, param_grid_lr, 'Logistic Regression')
]

# %% [markdown]
# ## Dataset Loading Functions
# We'll work with four different datasets to test our algorithms across various domains.

# %% [markdown]
# ### 3.1 Wine Quality Dataset

# %%
def load_wine_quality():
    """Load Wine Quality dataset"""
    url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv'
    try:
        data = pd.read_csv(url, sep=';')
    except Exception as e:
        print(f"Error loading Wine Quality dataset: {e}")
        return None, None, None, None, "Wine Quality (Failed)"

    # Create the binary target variable 'good_quality'
    data['good_quality'] = (data['quality'] > 5).astype(int)
    X = data.drop(['quality', 'good_quality'], axis=1)
    y = data['good_quality']

    # Train-test split
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.3, random_state=42, stratify=y
    )

    print("Wine Quality dataset loaded and preprocessed successfully.")
    print(f"Training set shape: {X_train.shape}")
    print(f"Testing set shape: {X_test.shape}")
    return X_train, X_test, y_train, y_test, "Wine Quality"

# %% [markdown]
# ### 3.2 HR Attrition Dataset

# %%
def load_hr_attrition():
    """Load IBM HR Attrition dataset"""
    try:
        data = pd.read_csv("data/WA_Fn-UseC_-HR-Employee-Attrition.csv")
    except FileNotFoundError:
        print("HR Attrition dataset not found. Please place 'WA_Fn-UseC_-HR-Employee-Attrition.csv' inside a 'data/' folder.")
        return None, None, None, None, "HR Attrition (Failed)"

    # Target: Attrition = Yes (1), No (0)
    data['Attrition'] = (data['Attrition'] == 'Yes').astype(int)

    # Drop ID-like column
    X = data.drop(['EmployeeNumber', 'Attrition'], axis=1, errors='ignore')
    y = data['Attrition']

    # One-hot encode categorical variables
    X = pd.get_dummies(X, drop_first=True)

    # Train-test split
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, stratify=y, test_size=0.3, random_state=42
    )

    print("IBM HR Attrition dataset loaded and preprocessed successfully.")
    print(f"Training set shape: {X_train.shape}")
    print(f"Testing set shape: {X_test.shape}")
    return X_train, X_test, y_train, y_test, "HR Attrition"

# %% [markdown]
# ### 3.3 Banknote Authentication Dataset

# %%
def load_banknote():
    """Load Banknote Authentication dataset"""
    url = "https://archive.ics.uci.edu/ml/machine-learning-databases/00267/data_banknote_authentication.txt"

    try:
        data = pd.read_csv(url, header=None)
    except Exception as e:
        print(f"Error loading Banknote dataset: {e}")
        return None, None, None, None, "Banknote (Failed)"

    # According to UCI: variance, skewness, curtosis, entropy, class (0=authentic, 1=fake)
    X = data.iloc[:, :-1]
    y = data.iloc[:, -1]

    # Train-test split
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, stratify=y, test_size=0.3, random_state=42
    )

    print("Banknote Authentication dataset loaded successfully.")
    print(f"Training set shape: {X_train.shape}")
    print(f"Testing set shape: {X_test.shape}")
    return X_train, X_test, y_train, y_test, "Banknote Authentication"

# %% [markdown]
# ### 3.4 QSAR Biodegradation Dataset

# %%
def load_qsar_biodegradation():
    """Load QSAR Biodegradation dataset"""
    url = "https://archive.ics.uci.edu/ml/machine-learning-databases/00254/biodeg.csv"

    try:
        data = pd.read_csv(url, sep=';', header=None)
    except Exception as e:
        print(f"Error loading QSAR dataset: {e}")
        return None, None, None, None, "QSAR (Failed)"

    # Last column is target (RB = ready biodegradable, NRB = not)
    X = data.iloc[:, :-1]
    y = (data.iloc[:, -1] == 'RB').astype(int)

    # Train-test split
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, stratify=y, test_size=0.3, random_state=42
    )

    print("QSAR Biodegradation dataset loaded successfully.")
    print(f"Training set shape: {X_train.shape}")
    print(f"Testing set shape: {X_test.shape}")
    return X_train, X_test, y_train, y_test, "QSAR Biodegradation"

# %% [markdown]
# ## Part 4: Manual Grid Search Implementation

# %%
def run_manual_grid_search(X_train, y_train, dataset_name):
    """Run manual grid search and return best estimators"""
    print(f"\n{'='*60}")
    print(f"RUNNING MANUAL GRID SEARCH FOR {dataset_name.upper()}")
    print(f"{'='*60}")

    best_estimators = {}
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

    # Adjust parameter grids based on dataset size
    n_features = X_train.shape[1]

    for classifier_instance, param_grid, name in classifiers_to_tune:
        print(f"--- Manual Grid Search for {name} ---")
        best_score = -1
        best_params = None

        # 1. Adjust the feature selection parameter grid to ensure 'k' does not exceed the number of features.
        adjusted_param_grid = dict(param_grid)
        if 'feature_selection__k' in adjusted_param_grid:
            k_values = [k for k in adjusted_param_grid['feature_selection__k'] if k <= n_features]
            if not k_values:
                # Fallback to valid k values if the original list is all > n_features
                k_values = list(range(1, min(20, n_features) + 1))
            adjusted_param_grid['feature_selection__k'] = k_values

        # 2. Generate all combinations of hyperparameters from the adjusted parameter grid.
        param_names = list(adjusted_param_grid.keys())
        param_values = list(adjusted_param_grid.values())
        param_combinations = list(itertools.product(*param_values))

        if len(param_combinations) == 0:
            print(f"Skipping {name}: empty parameter grid after adjustment.")
            continue

        print(f"Testing {len(param_combinations)} parameter combinations...")

        # 3. For each parameter combination:
        for i, param_combo in enumerate(param_combinations):
            # Create parameter dictionary for this combination
            current_params = dict(zip(param_names, param_combo))
            
            # a. Perform cross-validation (5-fold StratifiedKFold)
            fold_scores = []
            
            for train_idx, val_idx in cv.split(X_train, y_train):
                # b. For each fold:
                # i. Split the training data into training and validation sets
                X_train_fold = X_train.iloc[train_idx]
                X_val_fold = X_train.iloc[val_idx]
                y_train_fold = y_train.iloc[train_idx]
                y_val_fold = y_train.iloc[val_idx]
                
                # ii. Build a pipeline with scaling, feature selection, and the classifier
                pipeline = Pipeline(steps=[
                    ('scaler', StandardScaler()),
                    ('feature_selection', SelectKBest(f_classif)),
                    ('classifier', classifier_instance)
                ])
                
                # iii. Set the pipeline parameters for the current combination
                pipeline.set_params(**current_params)
                
                # iv. Fit the pipeline on the training fold
                pipeline.fit(X_train_fold, y_train_fold)
                
                # v. Predict probabilities on the validation fold
                y_pred_proba = pipeline.predict_proba(X_val_fold)[:, 1]
                
                # vi. Compute the AUC score for the fold
                fold_auc = roc_auc_score(y_val_fold, y_pred_proba)
                fold_scores.append(fold_auc)
            
            # c. Compute the mean AUC across all folds for the parameter combination
            mean_auc = np.mean(fold_scores)
            
            # d. Track and print the best parameter combination and its mean AUC
            if mean_auc > best_score:
                best_score = mean_auc
                best_params = current_params
                print(f"New best! Combination {i+1}/{len(param_combinations)}: AUC = {mean_auc:.4f}, Params: {current_params}")
            elif (i + 1) % 50 == 0:  # Print progress every 50 combinations
                print(f"Processed {i+1}/{len(param_combinations)} combinations...")

        # Create the final pipeline for this classifier
        print("-" * 90)
        print(f"Best parameters for {name}: {best_params}")
        print(f"Best cross-validation AUC: {best_score:.4f}")

        if best_params is None:
            print(f"No valid parameter set found for {name}. Skipping.")
            continue

        final_pipeline = Pipeline(steps=[
            ('scaler', StandardScaler()),
            ('feature_selection', SelectKBest(f_classif)),
            ('classifier', classifier_instance)
        ])

        # Set the best parameters found
        final_pipeline.set_params(**best_params)

        # Fit the final pipeline on the full training data
        final_pipeline.fit(X_train, y_train)

        # Store the fully trained best pipeline
        best_estimators[name] = final_pipeline

    return best_estimators

# %% [markdown]
# **Understanding the Manual Implementation**:
# - **Nested Cross-Validation**: For each parameter combination, we perform 5-fold CV
# - **Pipeline Integration**: Each step (scaling, feature selection, classification) is properly chained
# - **AUC Scoring**: We use Area Under the ROC Curve as our optimization metric
# - **Best Model Selection**: The combination with highest mean AUC across folds is selected

# %% [markdown]
# ## Part 5: Built-in Grid Search Implementation
#
# Now let's compare our manual implementation with scikit-learn's GridSearchCV.
#
#
#
# **Advantages of Built-in GridSearchCV**:
# - **Parallel Processing**: Uses `n_jobs=-1` for faster computation
# - **Cleaner Code**: Less verbose than manual implementation
# - **Built-in Features**: Automatic best model selection and scoring

# %%
def run_builtin_grid_search(X_train, y_train, dataset_name):
    """Run built-in grid search and return best estimators"""
    print(f"\n{'='*60}")
    print(f"RUNNING BUILT-IN GRID SEARCH FOR {dataset_name.upper()}")
    print(f"{'='*60}")

    results_builtin = {}

    # Adjust parameter grids based on dataset size
    n_features = X_train.shape[1]

    for classifier_instance, param_grid, name in classifiers_to_tune:
        print(f"\n--- GridSearchCV for {name} ---")

        # Adjust feature selection parameter grid based on dataset size (n_features)
        adjusted_param_grid = dict(param_grid)
        if 'feature_selection__k' in adjusted_param_grid:
            k_values = [k for k in adjusted_param_grid['feature_selection__k'] if k <= n_features]
            if not k_values:
                k_values = list(range(1, min(20, n_features) + 1))
            adjusted_param_grid['feature_selection__k'] = k_values

        # Compute number of combinations without materializing them
        n_combos = 1
        for v in adjusted_param_grid.values():
            n_combos *= len(v)
        if n_combos == 0:
            print(f"Skipping {name}: empty parameter grid after adjustment.")
            continue

        # Create a pipeline with StandardScaler, SelectKBest(f_classif), and the classifier
        pipeline = Pipeline(steps=[
            ('scaler', StandardScaler()),
            ('feature_selection', SelectKBest(f_classif)),
            ('classifier', classifier_instance)
        ])
        
        # Set up StratifiedKFold cross-validation
        cv_splitter = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

        # Run GridSearchCV with the pipeline and adjusted param grid
        grid_search = GridSearchCV(
            estimator=pipeline,
            param_grid=adjusted_param_grid,
            scoring='roc_auc',
            cv=cv_splitter,
            n_jobs=-1,  # Use all available cores for faster computation
            verbose=1   # Show progress
        )

        # Fit grid search on training data and collect best estimator/results
        print(f"Fitting GridSearchCV with {n_combos} parameter combinations...")
        grid_search.fit(X_train, y_train)

        # Save results
        results_builtin[name] = {
            'best_estimator': grid_search.best_estimator_,
            'best_score (CV)': grid_search.best_score_,
            'best_params': grid_search.best_params_
        }
        print(f"Best params for {name}: {results_builtin[name]['best_params']}")
        print(f"Best CV score: {results_builtin[name]['best_score (CV)']:.4f}")

    return results_builtin

# %% [markdown]
# ## Part 6: Model Evaluation and Voting Classifiers
#
# This function evaluates individual models and creates voting classifiers to combine their predictions.

# %%
def evaluate_models(X_train, X_test, y_train, y_test, best_estimators, dataset_name, method_name="Manual"):
    """Evaluate models and create visualizations"""
    print(f"\n{'='*60}")
    print(f"EVALUATING {method_name.upper()} MODELS FOR {dataset_name.upper()}")
    print(f"{'='*60}")

    # Individual model evaluation
    print(f"\n--- Individual Model Performance ---")
    for name, model in best_estimators.items():
        y_pred = model.predict(X_test)
        y_pred_proba = model.predict_proba(X_test)[:, 1]
        print(f"\n{name}:")
        print(f"  Accuracy: {accuracy_score(y_test, y_pred):.4f}")
        print(f"  Precision: {precision_score(y_test, y_pred, zero_division=0):.4f}")
        print(f"  Recall: {recall_score(y_test, y_pred, zero_division=0):.4f}")
        print(f"  F1-Score: {f1_score(y_test, y_pred, zero_division=0):.4f}")
        print(f"  ROC AUC: {roc_auc_score(y_test, y_pred_proba):.4f}")

    # Voting Classifier
    print(f"\n--- {method_name} Voting Classifier ---")

    if method_name == "Manual":
        # Manual voting implementation
        y_pred_votes = []
        y_pred_proba_avg = []

        for i in range(len(X_test)):
            votes = []
            probas = []

            for name, model in best_estimators.items():
                pred = model.predict(X_test.iloc[[i]])[0]
                proba = model.predict_proba(X_test.iloc[[i]])[0, 1]
                votes.append(pred)
                probas.append(proba)

            majority_vote = 1 if np.mean(votes) > 0.5 else 0
            avg_proba = np.mean(probas)

            y_pred_votes.append(majority_vote)
            y_pred_proba_avg.append(avg_proba)

        y_pred_votes = np.array(y_pred_votes)
        y_pred_proba_avg = np.array(y_pred_proba_avg)

    else:  # Built-in
        # Create VotingClassifier
        estimators = [(name, model) for name, model in best_estimators.items()]
        voting_clf = VotingClassifier(estimators=estimators, voting='soft')
        voting_clf.fit(X_train, y_train)  # Note: This assumes X_train, y_train are in scope

        y_pred_votes = voting_clf.predict(X_test)
        y_pred_proba_avg = voting_clf.predict_proba(X_test)[:, 1]

    # Compute voting metrics
    accuracy = accuracy_score(y_test, y_pred_votes)
    precision = precision_score(y_test, y_pred_votes, zero_division=0)
    recall = recall_score(y_test, y_pred_votes, zero_division=0)
    f1 = f1_score(y_test, y_pred_votes, zero_division=0)
    auc = roc_auc_score(y_test, y_pred_proba_avg)

    print(f"Voting Classifier Performance:")
    print(f"  Accuracy: {accuracy:.4f}, Precision: {precision:.4f}")
    print(f"  Recall: {recall:.4f}, F1: {f1:.4f}, AUC: {auc:.4f}")

    # Visualizations
    # ROC Curves
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    for name, model in best_estimators.items():
        y_pred_proba = model.predict_proba(X_test)[:, 1]
        fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
        auc_score = roc_auc_score(y_test, y_pred_proba)
        plt.plot(fpr, tpr, label=f'{name} (AUC = {auc_score:.3f})')

    # Add voting classifier to ROC
    fpr_vote, tpr_vote, _ = roc_curve(y_test, y_pred_proba_avg)
    plt.plot(fpr_vote, tpr_vote, label=f'Voting (AUC = {auc:.3f})', linewidth=3, linestyle='--')

    plt.plot([0, 1], [0, 1], 'k--', label='Chance')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curves - {dataset_name} ({method_name})')
    plt.legend()
    plt.grid(True)

    # Confusion Matrix for Voting Classifier
    plt.subplot(1, 2, 2)
    cm = confusion_matrix(y_test, y_pred_votes)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot(ax=plt.gca(), cmap="Blues")
    plt.title(f'Voting Classifier - {dataset_name} ({method_name})')

    plt.tight_layout()
    plt.show()

    return y_pred_votes, y_pred_proba_avg

# %% [markdown]
# ## Part 7: Complete Pipeline Function
#
# This function orchestrates the entire experiment for each dataset.

# %%
def run_complete_pipeline(dataset_loader, dataset_name):
    """Run complete pipeline for a dataset"""
    print(f"\n{'#'*80}")
    print(f"PROCESSING DATASET: {dataset_name.upper()}")
    print(f"{'#'*80}")

    # Load dataset
    X_train, X_test, y_train, y_test, actual_name = dataset_loader()
    if X_train is None:
        print(f"Skipping {dataset_name} due to loading error.")
        return

    print("-" * 30)

    # Part 1: Manual Implementation
    manual_estimators = run_manual_grid_search(X_train, y_train, actual_name)
    manual_votes, manual_proba = evaluate_models(X_train, X_test, y_train, y_test, manual_estimators, actual_name, "Manual")

    # Part 2: Built-in Implementation
    builtin_results = run_builtin_grid_search(X_train, y_train, actual_name)
    builtin_estimators = {name: results['best_estimator']
                         for name, results in builtin_results.items()}
    builtin_votes, builtin_proba = evaluate_models(X_train, X_test, y_train, y_test, builtin_estimators, actual_name, "Built-in")

    print(f"\nCompleted processing for {actual_name}")
    print("="*80)

# %% [markdown]
# ## Part 8: Execute the Complete Lab
#
# Now let's run our pipeline on all four datasets!

# %%
# --- Run Pipeline for All Datasets ---
datasets = [
    (load_wine_quality, "Wine Quality"),
    (load_hr_attrition, "HR Attrition"),
    (load_banknote, "Banknote Authentication"),
    (load_qsar_biodegradation, "QSAR Biodegradation")
]

# Run for each dataset
for dataset_loader, dataset_name in datasets:
    try:
        run_complete_pipeline(dataset_loader, dataset_name)
    except Exception as e:
        print(f"Error processing {dataset_name}: {e}")
        continue

print("\n" + "="*80)
print("ALL DATASETS PROCESSED!")
print("="*80)
# Out:
# ################################################################################
# PROCESSING DATASET: WINE QUALITY
# ################################################################################
# Wine Quality dataset loaded and preprocessed successfully.
# Training set shape: (1119, 11)
# Testing set shape: (480, 11)
# ------------------------------
#
# ============================================================
# RUNNING MANUAL GRID SEARCH FOR WINE QUALITY
# ============================================================
# --- Manual Grid Search for Decision Tree ---
# Testing 90 parameter combinations...
# New best! Combination 1/90: AUC = 0.7554, Params: {'feature_selection__k': 5, 'classifier__max_depth': 3, 'classifier__min_samples_split': 2, 'classifier__min_samples_leaf': 1}
# New best! Combination 10/90: AUC = 0.7796, Params: {'feature_selection__k': 5, 'classifier__max_depth': 5, 'classifier__min_samples_split': 2, 'classifier__min_samples_leaf': 1}
# New best! Combination 11/90: AUC = 0.7846, Params: {'feature_selection__k': 5, 'classifier__max_depth': 5, 'classifier__min_samples_split': 2, 'classifier__min_samples_leaf': 2}
# New best! Combination 36/90: AUC = 0.7849, Params: {'feature_selection__k': 5, 'classifier__max_depth': 10, 'classifier__min_samples_split': 10, 'classifier__min_samples_leaf': 4}
# Processed 50/90 combinations...
# ------------------------------------------------------------------------------------------
# Best parameters for Decision Tree: {'feature_selection__k': 5, 'classifier__max_depth': 10, 'classifier__min_samples_split': 10, 'classifier__min_samples_leaf': 4}
# Best cross-validation AUC: 0.7849
# --- Manual Grid Search for k-NN ---
# Testing 40 parameter combinations...
# New best! Combination 1/40: AUC = 0.7952, Params: {'feature_selection__k': 5, 'classifier__n_neighbors': 3, 'classifier__weights': 'uniform', 'classifier__metric': 'euclidean'}
# New best! Combination 3/40: AUC = 0.8352, Params: {'feature_selection__k': 5, 'classifier__n_neighbors': 3, 'classifier__weights': 'distance', 'classifier__metric': 'euclidean'}
# New best! Combination 7/40: AUC = 0.8502, Params: {'feature_selection__k': 5, 'classifier__n_neighbors': 5, 'classifier__weights': 'distance', 'classifier__metric': 'euclidean'}
# New best! Combination 8/40: AUC = 0.8579, Params: {'feature_selection__k': 5, 'classifier__n_neighbors': 5, 'classifier__weights': 'distance', 'classifier__metric': 'manhattan'}
# New best! Combination 11/40: AUC = 0.8603, Params: {'feature_selection__k': 5, 'classifier__n_neighbors': 7, 'classifier__weights': 'distance', 'classifier__metric': 'euclidean'}
# New best! Combination 12/40: AUC = 0.8667, Params: {'feature_selection__k': 5, 'classifier__n_neighbors': 7, 'classifier__weights': 'distance', 'classifier__metric': 'manhattan'}
# New best! Combination 19/40: AUC = 0.8670, Params: {'feature_selection__k': 5, 'classifier__n_neighbors': 11, 'classifier__weights': 'distance', 'classifier__metric': 'euclidean'}
# New best! Combination 20/40: AUC = 0.8696, Params: {'feature_selection__k': 5, 'classifier__n_neighbors': 11, 'classifier__weights': 'distance', 'classifier__metric': 'manhattan'}
# ------------------------------------------------------------------------------------------
# Best parameters for k-NN: {'feature_selection__k': 5, 'classifier__n_neighbors': 11, 'classifier__weights': 'distance', 'classifier__metric': 'manhattan'}
# Best cross-validation AUC: 0.8696
# --- Manual Grid Search for Logistic Regression ---
# Testing 40 parameter combinations...
# New best! Combination 1/40: AUC = 0.7711, Params: {'feature_selection__k': 5, 'classifier__C': 0.01, 'classifier__penalty': 'l1', 'classifier__solver': 'liblinear'}
# New best! Combination 3/40: AUC = 0.8009, Params: {'feature_selection__k': 5, 'classifier__C': 0.01, 'classifier__penalty': 'l2', 'classifier__solver': 'liblinear'}
# New best! Combination 5/40: AUC = 0.8035, Params: {'feature_selection__k': 5, 'classifier__C': 0.1, 'classifier__penalty': 'l1', 'classifier__solver': 'liblinear'}
# New best! Combination 27/40: AUC = 0.8046, Params: {'feature_selection__k': 10, 'classifier__C': 0.1, 'classifier__penalty': 'l2', 'classifier__solver': 'liblinear'}
# New best! Combination 28/40: AUC = 0.8046, Params: {'feature_selection__k': 10, 'classifier__C': 0.1, 'classifier__penalty': 'l2', 'classifier__solver': 'saga'}
# New best! Combination 31/40: AUC = 0.8049, Params: {'feature_selection__k': 10, 'classifier__C': 1, 'classifier__penalty': 'l2', 'classifier__solver': 'liblinear'}
# New best! Combination 32/40: AUC = 0.8049, Params: {'feature_selection__k': 10, 'classifier__C': 1, 'classifier__penalty': 'l2', 'classifier__solver': 'saga'}
# ------------------------------------------------------------------------------------------
# Best parameters for Logistic Regression: {'feature_selection__k': 10, 'classifier__C': 1, 'classifier__penalty': 'l2', 'classifier__solver': 'saga'}
# Best cross-validation AUC: 0.8049
#
# ============================================================
# EVALUATING MANUAL MODELS FOR WINE QUALITY
# ============================================================
#
# --- Individual Model Performance ---
#
# Decision Tree:
#   Accuracy: 0.7250
#   Precision: 0.7593
#   Recall: 0.7121
#   F1-Score: 0.7349
#   ROC AUC: 0.7908
#
# k-NN:
#   Accuracy: 0.7917
#   Precision: 0.7940
#   Recall: 0.8249
#   F1-Score: 0.8092
#   ROC AUC: 0.8765
#
# Logistic Regression:
#   Accuracy: 0.7417
#   Precision: 0.7628
#   Recall: 0.7510
#   F1-Score: 0.7569
#   ROC AUC: 0.8246
#
# --- Manual Voting Classifier ---
# Voting Classifier Performance:
#   Accuracy: 0.7542, Precision: 0.7683
#   Recall: 0.7743, F1: 0.7713, AUC: 0.8666
# ============================================================
# RUNNING BUILT-IN GRID SEARCH FOR WINE QUALITY
# ============================================================
#
# --- GridSearchCV for Decision Tree ---
# Fitting GridSearchCV with 90 parameter combinations...
# Fitting 5 folds for each of 90 candidates, totalling 450 fits
# Best params for Decision Tree: {'classifier__max_depth': 10, 'classifier__min_samples_leaf': 4, 'classifier__min_samples_split': 10, 'feature_selection__k': 5}
# Best CV score: 0.7849
#
# --- GridSearchCV for k-NN ---
# Fitting GridSearchCV with 40 parameter combinations...
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# Best params for k-NN: {'classifier__metric': 'manhattan', 'classifier__n_neighbors': 11, 'classifier__weights': 'distance', 'feature_selection__k': 5}
# Best CV score: 0.8696
#
# --- GridSearchCV for Logistic Regression ---
# Fitting GridSearchCV with 40 parameter combinations...
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# Best params for Logistic Regression: {'classifier__C': 1, 'classifier__penalty': 'l2', 'classifier__solver': 'saga', 'feature_selection__k': 10}
# Best CV score: 0.8049
#
# ============================================================
# EVALUATING BUILT-IN MODELS FOR WINE QUALITY
# ============================================================
#
# --- Individual Model Performance ---
#
# Decision Tree:
#   Accuracy: 0.7250
#   Precision: 0.7593
#   Recall: 0.7121
#   F1-Score: 0.7349
#   ROC AUC: 0.7908
#
# k-NN:
#   Accuracy: 0.7917
#   Precision: 0.7940
#   Recall: 0.8249
#   F1-Score: 0.8092
#   ROC AUC: 0.8765
#
# Logistic Regression:
#   Accuracy: 0.7417
#   Precision: 0.7628
#   Recall: 0.7510
#   F1-Score: 0.7569
#   ROC AUC: 0.8246
#
# --- Built-in Voting Classifier ---
# Voting Classifier Performance:
#   Accuracy: 0.7854, Precision: 0.7939
#   Recall: 0.8093, F1: 0.8015, AUC: 0.8666
# Completed processing for Wine Quality
# ================================================================================
#
# ################################################################################
# PROCESSING DATASET: HR ATTRITION
# ################################################################################
# HR Attrition dataset not found. Please place 'WA_Fn-UseC_-HR-Employee-Attrition.csv' inside a 'data/' folder.
# Skipping HR Attrition due to loading error.
#
# ################################################################################
# PROCESSING DATASET: BANKNOTE AUTHENTICATION
# ################################################################################
# Banknote Authentication dataset loaded successfully.
# Training set shape: (960, 4)
# Testing set shape: (412, 4)
# ------------------------------
#
# ============================================================
# RUNNING MANUAL GRID SEARCH FOR BANKNOTE AUTHENTICATION
# ============================================================
# --- Manual Grid Search for Decision Tree ---
# Testing 180 parameter combinations...
# New best! Combination 1/180: AUC = 0.9226, Params: {'feature_selection__k': 1, 'classifier__max_depth': 3, 'classifier__min_samples_split': 2, 'classifier__min_samples_leaf': 1}
# New best! Combination 2/180: AUC = 0.9241, Params: {'feature_selection__k': 1, 'classifier__max_depth': 3, 'classifier__min_samples_split': 2, 'classifier__min_samples_leaf': 2}
# New best! Combination 3/180: AUC = 0.9258, Params: {'feature_selection__k': 1, 'classifier__max_depth': 3, 'classifier__min_samples_split': 2, 'classifier__min_samples_leaf': 4}
# New best! Combination 46/180: AUC = 0.9676, Params: {'feature_selection__k': 2, 'classifier__max_depth': 3, 'classifier__min_samples_split': 2, 'classifier__min_samples_leaf': 1}
# Processed 50/180 combinations...
# New best! Combination 100/180: AUC = 0.9844, Params: {'feature_selection__k': 3, 'classifier__max_depth': 5, 'classifier__min_samples_split': 2, 'classifier__min_samples_leaf': 1}
# New best! Combination 101/180: AUC = 0.9875, Params: {'feature_selection__k': 3, 'classifier__max_depth': 5, 'classifier__min_samples_split': 2, 'classifier__min_samples_leaf': 2}
# New best! Combination 111/180: AUC = 0.9877, Params: {'feature_selection__k': 3, 'classifier__max_depth': 7, 'classifier__min_samples_split': 2, 'classifier__min_samples_leaf': 4}
# New best! Combination 116/180: AUC = 0.9889, Params: {'feature_selection__k': 3, 'classifier__max_depth': 7, 'classifier__min_samples_split': 10, 'classifier__min_samples_leaf': 2}
# Processed 150/180 combinations...
# ------------------------------------------------------------------------------------------
# Best parameters for Decision Tree: {'feature_selection__k': 3, 'classifier__max_depth': 7, 'classifier__min_samples_split': 10, 'classifier__min_samples_leaf': 2}
# Best cross-validation AUC: 0.9889
# --- Manual Grid Search for k-NN ---
# Testing 80 parameter combinations...
# New best! Combination 1/80: AUC = 0.8757, Params: {'feature_selection__k': 1, 'classifier__n_neighbors': 3, 'classifier__weights': 'uniform', 'classifier__metric': 'euclidean'}
# New best! Combination 5/80: AUC = 0.8947, Params: {'feature_selection__k': 1, 'classifier__n_neighbors': 5, 'classifier__weights': 'uniform', 'classifier__metric': 'euclidean'}
# New best! Combination 9/80: AUC = 0.9081, Params: {'feature_selection__k': 1, 'classifier__n_neighbors': 7, 'classifier__weights': 'uniform', 'classifier__metric': 'euclidean'}
# New best! Combination 13/80: AUC = 0.9135, Params: {'feature_selection__k': 1, 'classifier__n_neighbors': 9, 'classifier__weights': 'uniform', 'classifier__metric': 'euclidean'}
# New best! Combination 17/80: AUC = 0.9169, Params: {'feature_selection__k': 1, 'classifier__n_neighbors': 11, 'classifier__weights': 'uniform', 'classifier__metric': 'euclidean'}
# New best! Combination 21/80: AUC = 0.9713, Params: {'feature_selection__k': 2, 'classifier__n_neighbors': 3, 'classifier__weights': 'uniform', 'classifier__metric': 'euclidean'}
# New best! Combination 22/80: AUC = 0.9727, Params: {'feature_selection__k': 2, 'classifier__n_neighbors': 3, 'classifier__weights': 'uniform', 'classifier__metric': 'manhattan'}
# New best! Combination 23/80: AUC = 0.9735, Params: {'feature_selection__k': 2, 'classifier__n_neighbors': 3, 'classifier__weights': 'distance', 'classifier__metric': 'euclidean'}
# New best! Combination 24/80: AUC = 0.9750, Params: {'feature_selection__k': 2, 'classifier__n_neighbors': 3, 'classifier__weights': 'distance', 'classifier__metric': 'manhattan'}
# New best! Combination 25/80: AUC = 0.9799, Params: {'feature_selection__k': 2, 'classifier__n_neighbors': 5, 'classifier__weights': 'uniform', 'classifier__metric': 'euclidean'}
# New best! Combination 27/80: AUC = 0.9819, Params: {'feature_selection__k': 2, 'classifier__n_neighbors': 5, 'classifier__weights': 'distance', 'classifier__metric': 'euclidean'}
# New best! Combination 29/80: AUC = 0.9819, Params: {'feature_selection__k': 2, 'classifier__n_neighbors': 7, 'classifier__weights': 'uniform', 'classifier__metric': 'euclidean'}
# New best! Combination 30/80: AUC = 0.9828, Params: {'feature_selection__k': 2, 'classifier__n_neighbors': 7, 'classifier__weights': 'uniform', 'classifier__metric': 'manhattan'}
# New best! Combination 31/80: AUC = 0.9837, Params: {'feature_selection__k': 2, 'classifier__n_neighbors': 7, 'classifier__weights': 'distance', 'classifier__metric': 'euclidean'}
# New best! Combination 32/80: AUC = 0.9844, Params: {'feature_selection__k': 2, 'classifier__n_neighbors': 7, 'classifier__weights': 'distance', 'classifier__metric': 'manhattan'}
# New best! Combination 35/80: AUC = 0.9863, Params: {'feature_selection__k': 2, 'classifier__n_neighbors': 9, 'classifier__weights': 'distance', 'classifier__metric': 'euclidean'}
# New best! Combination 39/80: AUC = 0.9870, Params: {'feature_selection__k': 2, 'classifier__n_neighbors': 11, 'classifier__weights': 'distance', 'classifier__metric': 'euclidean'}
# New best! Combination 41/80: AUC = 0.9991, Params: {'feature_selection__k': 3, 'classifier__n_neighbors': 3, 'classifier__weights': 'uniform', 'classifier__metric': 'euclidean'}
# New best! Combination 45/80: AUC = 0.9999, Params: {'feature_selection__k': 3, 'classifier__n_neighbors': 5, 'classifier__weights': 'uniform', 'classifier__metric': 'euclidean'}
# New best! Combination 47/80: AUC = 1.0000, Params: {'feature_selection__k': 3, 'classifier__n_neighbors': 5, 'classifier__weights': 'distance', 'classifier__metric': 'euclidean'}
# Processed 50/80 combinations...
# ------------------------------------------------------------------------------------------
# Best parameters for k-NN: {'feature_selection__k': 3, 'classifier__n_neighbors': 5, 'classifier__weights': 'distance', 'classifier__metric': 'euclidean'}
# Best cross-validation AUC: 1.0000
# --- Manual Grid Search for Logistic Regression ---
# Testing 80 parameter combinations...
# New best! Combination 1/80: AUC = 0.9243, Params: {'feature_selection__k': 1, 'classifier__C': 0.01, 'classifier__penalty': 'l1', 'classifier__solver': 'liblinear'}
# New best! Combination 21/80: AUC = 0.9389, Params: {'feature_selection__k': 2, 'classifier__C': 0.01, 'classifier__penalty': 'l1', 'classifier__solver': 'liblinear'}
# New best! Combination 23/80: AUC = 0.9546, Params: {'feature_selection__k': 2, 'classifier__C': 0.01, 'classifier__penalty': 'l2', 'classifier__solver': 'liblinear'}
# New best! Combination 27/80: AUC = 0.9548, Params: {'feature_selection__k': 2, 'classifier__C': 0.1, 'classifier__penalty': 'l2', 'classifier__solver': 'liblinear'}
# New best! Combination 28/80: AUC = 0.9548, Params: {'feature_selection__k': 2, 'classifier__C': 0.1, 'classifier__penalty': 'l2', 'classifier__solver': 'saga'}
# New best! Combination 31/80: AUC = 0.9549, Params: {'feature_selection__k': 2, 'classifier__C': 1, 'classifier__penalty': 'l2', 'classifier__solver': 'liblinear'}
# New best! Combination 43/80: AUC = 0.9867, Params: {'feature_selection__k': 3, 'classifier__C': 0.01, 'classifier__penalty': 'l2', 'classifier__solver': 'liblinear'}
# New best! Combination 44/80: AUC = 0.9867, Params: {'feature_selection__k': 3, 'classifier__C': 0.01, 'classifier__penalty': 'l2', 'classifier__solver': 'saga'}
# New best! Combination 45/80: AUC = 0.9992, Params: {'feature_selection__k': 3, 'classifier__C': 0.1, 'classifier__penalty': 'l1', 'classifier__solver': 'liblinear'}
# New best! Combination 46/80: AUC = 0.9992, Params: {'feature_selection__k': 3, 'classifier__C': 0.1, 'classifier__penalty': 'l1', 'classifier__solver': 'saga'}
# New best! Combination 49/80: AUC = 0.9995, Params: {'feature_selection__k': 3, 'classifier__C': 1, 'classifier__penalty': 'l1', 'classifier__solver': 'liblinear'}
# Processed 50/80 combinations...
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# New best! Combination 73/80: AUC = 0.9995, Params: {'feature_selection__k': 4, 'classifier__C': 10, 'classifier__penalty': 'l1', 'classifier__solver': 'liblinear'}
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# New best! Combination 74/80: AUC = 0.9996, Params: {'feature_selection__k': 4, 'classifier__C': 10, 'classifier__penalty': 'l1', 'classifier__solver': 'saga'}
# New best! Combination 77/80: AUC = 0.9996, Params: {'feature_selection__k': 4, 'classifier__C': 100, 'classifier__penalty': 'l1', 'classifier__solver': 'liblinear'}
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# New best! Combination 78/80: AUC = 0.9997, Params: {'feature_selection__k': 4, 'classifier__C': 100, 'classifier__penalty': 'l1', 'classifier__solver': 'saga'}
# ------------------------------------------------------------------------------------------
# Best parameters for Logistic Regression: {'feature_selection__k': 4, 'classifier__C': 100, 'classifier__penalty': 'l1', 'classifier__solver': 'saga'}
# Best cross-validation AUC: 0.9997
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# ============================================================
# EVALUATING MANUAL MODELS FOR BANKNOTE AUTHENTICATION
# ============================================================
#
# --- Individual Model Performance ---
#
# Decision Tree:
#   Accuracy: 0.9806
#   Precision: 0.9944
#   Recall: 0.9617
#   F1-Score: 0.9778
#   ROC AUC: 0.9918
#
# k-NN:
#   Accuracy: 1.0000
#   Precision: 1.0000
#   Recall: 1.0000
#   F1-Score: 1.0000
#   ROC AUC: 1.0000
#
# Logistic Regression:
#   Accuracy: 0.9879
#   Precision: 0.9785
#   Recall: 0.9945
#   F1-Score: 0.9864
#   ROC AUC: 0.9999
#
# --- Manual Voting Classifier ---
# Voting Classifier Performance:
#   Accuracy: 0.9976, Precision: 1.0000
#   Recall: 0.9945, F1: 0.9973, AUC: 1.0000
# ============================================================
# RUNNING BUILT-IN GRID SEARCH FOR BANKNOTE AUTHENTICATION
# ============================================================
#
# --- GridSearchCV for Decision Tree ---
# Fitting GridSearchCV with 180 parameter combinations...
# Fitting 5 folds for each of 180 candidates, totalling 900 fits
# Best params for Decision Tree: {'classifier__max_depth': 7, 'classifier__min_samples_leaf': 2, 'classifier__min_samples_split': 10, 'feature_selection__k': 3}
# Best CV score: 0.9889
#
# --- GridSearchCV for k-NN ---
# Fitting GridSearchCV with 80 parameter combinations...
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params for k-NN: {'classifier__metric': 'euclidean', 'classifier__n_neighbors': 5, 'classifier__weights': 'distance', 'feature_selection__k': 3}
# Best CV score: 1.0000
#
# --- GridSearchCV for Logistic Regression ---
# Fitting GridSearchCV with 80 parameter combinations...
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Best params for Logistic Regression: {'classifier__C': 100, 'classifier__penalty': 'l1', 'classifier__solver': 'saga', 'feature_selection__k': 4}
# Best CV score: 0.9997
#
# ============================================================
# EVALUATING BUILT-IN MODELS FOR BANKNOTE AUTHENTICATION
# ============================================================
#
# --- Individual Model Performance ---
#
# Decision Tree:
#   Accuracy: 0.9806
#   Precision: 0.9944
#   Recall: 0.9617
#   F1-Score: 0.9778
#   ROC AUC: 0.9918
#
# k-NN:
#   Accuracy: 1.0000
#   Precision: 1.0000
#   Recall: 1.0000
#   F1-Score: 1.0000
#   ROC AUC: 1.0000
#
# Logistic Regression:
#   Accuracy: 0.9879
#   Precision: 0.9785
#   Recall: 0.9945
#   F1-Score: 0.9864
#   ROC AUC: 0.9999
#
# --- Built-in Voting Classifier ---
# Voting Classifier Performance:
#   Accuracy: 0.9976, Precision: 1.0000
#   Recall: 0.9945, F1: 0.9973, AUC: 1.0000
# Completed processing for Banknote Authentication
# ================================================================================
#
# ################################################################################
# PROCESSING DATASET: QSAR BIODEGRADATION
# ################################################################################
# QSAR Biodegradation dataset loaded successfully.
# Training set shape: (738, 41)
# Testing set shape: (317, 41)
# ------------------------------
#
# ============================================================
# RUNNING MANUAL GRID SEARCH FOR QSAR BIODEGRADATION
# ============================================================
# --- Manual Grid Search for Decision Tree ---
# Testing 180 parameter combinations...
# New best! Combination 1/180: AUC = 0.7902, Params: {'feature_selection__k': 5, 'classifier__max_depth': 3, 'classifier__min_samples_split': 2, 'classifier__min_samples_leaf': 1}
# New best! Combination 3/180: AUC = 0.7938, Params: {'feature_selection__k': 5, 'classifier__max_depth': 3, 'classifier__min_samples_split': 2, 'classifier__min_samples_leaf': 4}
# New best! Combination 9/180: AUC = 0.7938, Params: {'feature_selection__k': 5, 'classifier__max_depth': 3, 'classifier__min_samples_split': 10, 'classifier__min_samples_leaf': 4}
# New best! Combination 10/180: AUC = 0.7979, Params: {'feature_selection__k': 5, 'classifier__max_depth': 5, 'classifier__min_samples_split': 2, 'classifier__min_samples_leaf': 1}
# New best! Combination 11/180: AUC = 0.7996, Params: {'feature_selection__k': 5, 'classifier__max_depth': 5, 'classifier__min_samples_split': 2, 'classifier__min_samples_leaf': 2}
# New best! Combination 12/180: AUC = 0.8016, Params: {'feature_selection__k': 5, 'classifier__max_depth': 5, 'classifier__min_samples_split': 2, 'classifier__min_samples_leaf': 4}
# New best! Combination 17/180: AUC = 0.8021, Params: {'feature_selection__k': 5, 'classifier__max_depth': 5, 'classifier__min_samples_split': 10, 'classifier__min_samples_leaf': 2}
# New best! Combination 46/180: AUC = 0.8192, Params: {'feature_selection__k': 10, 'classifier__max_depth': 3, 'classifier__min_samples_split': 2, 'classifier__min_samples_leaf': 1}
# Processed 50/180 combinations...
# New best! Combination 57/180: AUC = 0.8400, Params: {'feature_selection__k': 10, 'classifier__max_depth': 5, 'classifier__min_samples_split': 2, 'classifier__min_samples_leaf': 4}
# Processed 100/180 combinations...
# New best! Combination 111/180: AUC = 0.8408, Params: {'feature_selection__k': 15, 'classifier__max_depth': 7, 'classifier__min_samples_split': 2, 'classifier__min_samples_leaf': 4}
# Processed 150/180 combinations...
# New best! Combination 156/180: AUC = 0.8502, Params: {'feature_selection__k': 20, 'classifier__max_depth': 7, 'classifier__min_samples_split': 2, 'classifier__min_samples_leaf': 4}
# New best! Combination 162/180: AUC = 0.8536, Params: {'feature_selection__k': 20, 'classifier__max_depth': 7, 'classifier__min_samples_split': 10, 'classifier__min_samples_leaf': 4}
# ------------------------------------------------------------------------------------------
# Best parameters for Decision Tree: {'feature_selection__k': 20, 'classifier__max_depth': 7, 'classifier__min_samples_split': 10, 'classifier__min_samples_leaf': 4}
# Best cross-validation AUC: 0.8536
# --- Manual Grid Search for k-NN ---
# Testing 80 parameter combinations...
# New best! Combination 1/80: AUC = 0.8047, Params: {'feature_selection__k': 5, 'classifier__n_neighbors': 3, 'classifier__weights': 'uniform', 'classifier__metric': 'euclidean'}
# New best! Combination 3/80: AUC = 0.8070, Params: {'feature_selection__k': 5, 'classifier__n_neighbors': 3, 'classifier__weights': 'distance', 'classifier__metric': 'euclidean'}
# New best! Combination 5/80: AUC = 0.8189, Params: {'feature_selection__k': 5, 'classifier__n_neighbors': 5, 'classifier__weights': 'uniform', 'classifier__metric': 'euclidean'}
# New best! Combination 6/80: AUC = 0.8249, Params: {'feature_selection__k': 5, 'classifier__n_neighbors': 5, 'classifier__weights': 'uniform', 'classifier__metric': 'manhattan'}
# New best! Combination 10/80: AUC = 0.8294, Params: {'feature_selection__k': 5, 'classifier__n_neighbors': 7, 'classifier__weights': 'uniform', 'classifier__metric': 'manhattan'}
# New best! Combination 21/80: AUC = 0.8420, Params: {'feature_selection__k': 10, 'classifier__n_neighbors': 3, 'classifier__weights': 'uniform', 'classifier__metric': 'euclidean'}
# New best! Combination 22/80: AUC = 0.8548, Params: {'feature_selection__k': 10, 'classifier__n_neighbors': 3, 'classifier__weights': 'uniform', 'classifier__metric': 'manhattan'}
# New best! Combination 24/80: AUC = 0.8582, Params: {'feature_selection__k': 10, 'classifier__n_neighbors': 3, 'classifier__weights': 'distance', 'classifier__metric': 'manhattan'}
# New best! Combination 25/80: AUC = 0.8585, Params: {'feature_selection__k': 10, 'classifier__n_neighbors': 5, 'classifier__weights': 'uniform', 'classifier__metric': 'euclidean'}
# New best! Combination 26/80: AUC = 0.8626, Params: {'feature_selection__k': 10, 'classifier__n_neighbors': 5, 'classifier__weights': 'uniform', 'classifier__metric': 'manhattan'}
# New best! Combination 27/80: AUC = 0.8673, Params: {'feature_selection__k': 10, 'classifier__n_neighbors': 5, 'classifier__weights': 'distance', 'classifier__metric': 'euclidean'}
# New best! Combination 28/80: AUC = 0.8677, Params: {'feature_selection__k': 10, 'classifier__n_neighbors': 5, 'classifier__weights': 'distance', 'classifier__metric': 'manhattan'}
# New best! Combination 30/80: AUC = 0.8687, Params: {'feature_selection__k': 10, 'classifier__n_neighbors': 7, 'classifier__weights': 'uniform', 'classifier__metric': 'manhattan'}
# New best! Combination 31/80: AUC = 0.8757, Params: {'feature_selection__k': 10, 'classifier__n_neighbors': 7, 'classifier__weights': 'distance', 'classifier__metric': 'euclidean'}
# New best! Combination 35/80: AUC = 0.8773, Params: {'feature_selection__k': 10, 'classifier__n_neighbors': 9, 'classifier__weights': 'distance', 'classifier__metric': 'euclidean'}
# New best! Combination 36/80: AUC = 0.8799, Params: {'feature_selection__k': 10, 'classifier__n_neighbors': 9, 'classifier__weights': 'distance', 'classifier__metric': 'manhattan'}
# New best! Combination 40/80: AUC = 0.8822, Params: {'feature_selection__k': 10, 'classifier__n_neighbors': 11, 'classifier__weights': 'distance', 'classifier__metric': 'manhattan'}
# Processed 50/80 combinations...
# New best! Combination 51/80: AUC = 0.8837, Params: {'feature_selection__k': 15, 'classifier__n_neighbors': 7, 'classifier__weights': 'distance', 'classifier__metric': 'euclidean'}
# New best! Combination 52/80: AUC = 0.8863, Params: {'feature_selection__k': 15, 'classifier__n_neighbors': 7, 'classifier__weights': 'distance', 'classifier__metric': 'manhattan'}
# New best! Combination 56/80: AUC = 0.8874, Params: {'feature_selection__k': 15, 'classifier__n_neighbors': 9, 'classifier__weights': 'distance', 'classifier__metric': 'manhattan'}
# New best! Combination 68/80: AUC = 0.8953, Params: {'feature_selection__k': 20, 'classifier__n_neighbors': 5, 'classifier__weights': 'distance', 'classifier__metric': 'manhattan'}
# New best! Combination 72/80: AUC = 0.8957, Params: {'feature_selection__k': 20, 'classifier__n_neighbors': 7, 'classifier__weights': 'distance', 'classifier__metric': 'manhattan'}
# New best! Combination 76/80: AUC = 0.8972, Params: {'feature_selection__k': 20, 'classifier__n_neighbors': 9, 'classifier__weights': 'distance', 'classifier__metric': 'manhattan'}
# New best! Combination 80/80: AUC = 0.8977, Params: {'feature_selection__k': 20, 'classifier__n_neighbors': 11, 'classifier__weights': 'distance', 'classifier__metric': 'manhattan'}
# ------------------------------------------------------------------------------------------
# Best parameters for k-NN: {'feature_selection__k': 20, 'classifier__n_neighbors': 11, 'classifier__weights': 'distance', 'classifier__metric': 'manhattan'}
# Best cross-validation AUC: 0.8977
# --- Manual Grid Search for Logistic Regression ---
# Testing 80 parameter combinations...
# New best! Combination 1/80: AUC = 0.7910, Params: {'feature_selection__k': 5, 'classifier__C': 0.01, 'classifier__penalty': 'l1', 'classifier__solver': 'liblinear'}
# New best! Combination 3/80: AUC = 0.8141, Params: {'feature_selection__k': 5, 'classifier__C': 0.01, 'classifier__penalty': 'l2', 'classifier__solver': 'liblinear'}
# New best! Combination 5/80: AUC = 0.8186, Params: {'feature_selection__k': 5, 'classifier__C': 0.1, 'classifier__penalty': 'l1', 'classifier__solver': 'liblinear'}
# New best! Combination 7/80: AUC = 0.8217, Params: {'feature_selection__k': 5, 'classifier__C': 0.1, 'classifier__penalty': 'l2', 'classifier__solver': 'liblinear'}
# New best! Combination 9/80: AUC = 0.8220, Params: {'feature_selection__k': 5, 'classifier__C': 1, 'classifier__penalty': 'l1', 'classifier__solver': 'liblinear'}
# New best! Combination 11/80: AUC = 0.8227, Params: {'feature_selection__k': 5, 'classifier__C': 1, 'classifier__penalty': 'l2', 'classifier__solver': 'liblinear'}
# New best! Combination 23/80: AUC = 0.8420, Params: {'feature_selection__k': 10, 'classifier__C': 0.01, 'classifier__penalty': 'l2', 'classifier__solver': 'liblinear'}
# New best! Combination 25/80: AUC = 0.8533, Params: {'feature_selection__k': 10, 'classifier__C': 0.1, 'classifier__penalty': 'l1', 'classifier__solver': 'liblinear'}
# New best! Combination 26/80: AUC = 0.8533, Params: {'feature_selection__k': 10, 'classifier__C': 0.1, 'classifier__penalty': 'l1', 'classifier__solver': 'saga'}
# New best! Combination 27/80: AUC = 0.8538, Params: {'feature_selection__k': 10, 'classifier__C': 0.1, 'classifier__penalty': 'l2', 'classifier__solver': 'liblinear'}
# New best! Combination 29/80: AUC = 0.8575, Params: {'feature_selection__k': 10, 'classifier__C': 1, 'classifier__penalty': 'l1', 'classifier__solver': 'liblinear'}
# New best! Combination 31/80: AUC = 0.8580, Params: {'feature_selection__k': 10, 'classifier__C': 1, 'classifier__penalty': 'l2', 'classifier__solver': 'liblinear'}
# New best! Combination 33/80: AUC = 0.8583, Params: {'feature_selection__k': 10, 'classifier__C': 10, 'classifier__penalty': 'l1', 'classifier__solver': 'liblinear'}
# New best! Combination 34/80: AUC = 0.8583, Params: {'feature_selection__k': 10, 'classifier__C': 10, 'classifier__penalty': 'l1', 'classifier__solver': 'saga'}
# New best! Combination 35/80: AUC = 0.8585, Params: {'feature_selection__k': 10, 'classifier__C': 10, 'classifier__penalty': 'l2', 'classifier__solver': 'liblinear'}
# New best! Combination 43/80: AUC = 0.8699, Params: {'feature_selection__k': 15, 'classifier__C': 0.01, 'classifier__penalty': 'l2', 'classifier__solver': 'liblinear'}
# New best! Combination 44/80: AUC = 0.8714, Params: {'feature_selection__k': 15, 'classifier__C': 0.01, 'classifier__penalty': 'l2', 'classifier__solver': 'saga'}
# New best! Combination 45/80: AUC = 0.8751, Params: {'feature_selection__k': 15, 'classifier__C': 0.1, 'classifier__penalty': 'l1', 'classifier__solver': 'liblinear'}
# New best! Combination 46/80: AUC = 0.8761, Params: {'feature_selection__k': 15, 'classifier__C': 0.1, 'classifier__penalty': 'l1', 'classifier__solver': 'saga'}
# New best! Combination 47/80: AUC = 0.8762, Params: {'feature_selection__k': 15, 'classifier__C': 0.1, 'classifier__penalty': 'l2', 'classifier__solver': 'liblinear'}
# New best! Combination 48/80: AUC = 0.8766, Params: {'feature_selection__k': 15, 'classifier__C': 0.1, 'classifier__penalty': 'l2', 'classifier__solver': 'saga'}
# New best! Combination 49/80: AUC = 0.8784, Params: {'feature_selection__k': 15, 'classifier__C': 1, 'classifier__penalty': 'l1', 'classifier__solver': 'liblinear'}
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# New best! Combination 50/80: AUC = 0.8784, Params: {'feature_selection__k': 15, 'classifier__C': 1, 'classifier__penalty': 'l1', 'classifier__solver': 'saga'}
# New best! Combination 51/80: AUC = 0.8793, Params: {'feature_selection__k': 15, 'classifier__C': 1, 'classifier__penalty': 'l2', 'classifier__solver': 'liblinear'}
# New best! Combination 53/80: AUC = 0.8817, Params: {'feature_selection__k': 15, 'classifier__C': 10, 'classifier__penalty': 'l1', 'classifier__solver': 'liblinear'}
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# New best! Combination 57/80: AUC = 0.8818, Params: {'feature_selection__k': 15, 'classifier__C': 100, 'classifier__penalty': 'l1', 'classifier__solver': 'liblinear'}
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# New best! Combination 63/80: AUC = 0.8875, Params: {'feature_selection__k': 20, 'classifier__C': 0.01, 'classifier__penalty': 'l2', 'classifier__solver': 'liblinear'}
# New best! Combination 64/80: AUC = 0.8886, Params: {'feature_selection__k': 20, 'classifier__C': 0.01, 'classifier__penalty': 'l2', 'classifier__solver': 'saga'}
# New best! Combination 65/80: AUC = 0.8929, Params: {'feature_selection__k': 20, 'classifier__C': 0.1, 'classifier__penalty': 'l1', 'classifier__solver': 'liblinear'}
# New best! Combination 66/80: AUC = 0.8947, Params: {'feature_selection__k': 20, 'classifier__C': 0.1, 'classifier__penalty': 'l1', 'classifier__solver': 'saga'}
# New best! Combination 67/80: AUC = 0.9044, Params: {'feature_selection__k': 20, 'classifier__C': 0.1, 'classifier__penalty': 'l2', 'classifier__solver': 'liblinear'}
# New best! Combination 68/80: AUC = 0.9062, Params: {'feature_selection__k': 20, 'classifier__C': 0.1, 'classifier__penalty': 'l2', 'classifier__solver': 'saga'}
# New best! Combination 69/80: AUC = 0.9144, Params: {'feature_selection__k': 20, 'classifier__C': 1, 'classifier__penalty': 'l1', 'classifier__solver': 'liblinear'}
# New best! Combination 72/80: AUC = 0.9144, Params: {'feature_selection__k': 20, 'classifier__C': 1, 'classifier__penalty': 'l2', 'classifier__solver': 'saga'}
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# ------------------------------------------------------------------------------------------
# Best parameters for Logistic Regression: {'feature_selection__k': 20, 'classifier__C': 1, 'classifier__penalty': 'l2', 'classifier__solver': 'saga'}
# Best cross-validation AUC: 0.9144
#
# ============================================================
# EVALUATING MANUAL MODELS FOR QSAR BIODEGRADATION
# ============================================================
#
# --- Individual Model Performance ---
#
# Decision Tree:
#   Accuracy: 0.7823
#   Precision: 0.6792
#   Recall: 0.6729
#   F1-Score: 0.6761
#   ROC AUC: 0.8211
#
# k-NN:
#   Accuracy: 0.8202
#   Precision: 0.7358
#   Recall: 0.7290
#   F1-Score: 0.7324
#   ROC AUC: 0.8799
#
# Logistic Regression:
#   Accuracy: 0.8360
#   Precision: 0.7895
#   Recall: 0.7009
#   F1-Score: 0.7426
#   ROC AUC: 0.8941
#
# --- Manual Voting Classifier ---
# Voting Classifier Performance:
#   Accuracy: 0.8486, Precision: 0.7980
#   Recall: 0.7383, F1: 0.7670, AUC: 0.9055
# ============================================================
# RUNNING BUILT-IN GRID SEARCH FOR QSAR BIODEGRADATION
# ============================================================
#
# --- GridSearchCV for Decision Tree ---
# Fitting GridSearchCV with 180 parameter combinations...
# Fitting 5 folds for each of 180 candidates, totalling 900 fits
# Best params for Decision Tree: {'classifier__max_depth': 7, 'classifier__min_samples_leaf': 4, 'classifier__min_samples_split': 10, 'feature_selection__k': 20}
# Best CV score: 0.8536
#
# --- GridSearchCV for k-NN ---
# Fitting GridSearchCV with 80 parameter combinations...
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best params for k-NN: {'classifier__metric': 'manhattan', 'classifier__n_neighbors': 11, 'classifier__weights': 'distance', 'feature_selection__k': 20}
# Best CV score: 0.8977
#
# --- GridSearchCV for Logistic Regression ---
# Fitting GridSearchCV with 80 parameter combinations...
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/hafizmohammedaahil/miniforge3/envs/main-ai-dev/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Best params for Logistic Regression: {'classifier__C': 1, 'classifier__penalty': 'l2', 'classifier__solver': 'saga', 'feature_selection__k': 20}
# Best CV score: 0.9144
#
# ============================================================
# EVALUATING BUILT-IN MODELS FOR QSAR BIODEGRADATION
# ============================================================
#
# --- Individual Model Performance ---
#
# Decision Tree:
#   Accuracy: 0.7823
#   Precision: 0.6792
#   Recall: 0.6729
#   F1-Score: 0.6761
#   ROC AUC: 0.8211
#
# k-NN:
#   Accuracy: 0.8202
#   Precision: 0.7358
#   Recall: 0.7290
#   F1-Score: 0.7324
#   ROC AUC: 0.8799
#
# Logistic Regression:
#   Accuracy: 0.8360
#   Precision: 0.7895
#   Recall: 0.7009
#   F1-Score: 0.7426
#   ROC AUC: 0.8941
#
# --- Built-in Voting Classifier ---
# Voting Classifier Performance:
#   Accuracy: 0.8360, Precision: 0.7778
#   Recall: 0.7196, F1: 0.7476, AUC: 0.9055
# Completed processing for QSAR Biodegradation
# ================================================================================
#
# ================================================================================
# ALL DATASETS PROCESSED!
# ================================================================================
